# %% [markdown]
# # Working with JSON
# * JSON is the preferred method to share data accross platforms
# * Many calls to web-based service return JSON
# * Dicts are very nearly JSON
# * Main methods are load, loads, dump dumps

# %%
import json
import requests

# %%
accounts = {'accounts': [
    {'account': 100, 'Name' : 'Smith', 'Balance' : 24.98},
    {'account' : 200, 'Name' : 'Johnson', 'Balance' : 345.67},
    {'account' : 300, 'Name' : 'Jones', 'Balance': 0.00}]}

# %%
accounts['accounts'][0]
# Out:
# {'account': 100, 'Name': 'Smith', 'Balance': 24.98}

# %%
accounts['accounts']
# Out:
# [{'account': 100, 'Name': 'Smith', 'Balance': 24.98},
#  {'account': 200, 'Name': 'Johnson', 'Balance': 345.67},
#  {'account': 300, 'Name': 'Jones', 'Balance': 0.0}]

# %%
for account in accounts['accounts']:
    print(account['Name'])
# Out:
# Smith
# Johnson
# Jones

# %%
carts = requests.get("https://dummyjson.com/carts").text
json.loads(carts)
# Out:
# {'carts': [{'id': 1,
#    'products': [{'id': 59,
#      'title': 'Spring and summershoes',
#      'price': 20,
#      'quantity': 3,
#      'total': 60,
#      'discountPercentage': 8.71,
#      'discountedPrice': 55,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/59/thumbnail.jpg'},
#     {'id': 88,
#      'title': 'TC Reusable Silicone Magic Washing Gloves',
#      'price': 29,
#      'quantity': 2,
#      'total': 58,
#      'discountPercentage': 3.19,
#      'discountedPrice': 56,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/88/thumbnail.jpg'},
#     {'id': 18,
#      'title': 'Oil Free Moisturizer 100ml',
#      'price': 40,
#      'quantity': 2,
#      'total': 80,
#      'discountPercentage': 13.1,
#      'discountedPrice': 70,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/18/thumbnail.jpg'},
#     {'id': 95,
#      'title': 'Wholesale cargo lashing Belt',
#      'price': 930,
#      'quantity': 1,
#      'total': 930,
#      'discountPercentage': 17.67,
#      'discountedPrice': 766,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/95/thumbnail.jpg'},
#     {'id': 39,
#      'title': 'Women Sweaters Wool',
#      'price': 600,
#      'quantity': 2,
#      'total': 1200,
#      'discountPercentage': 17.2,
#      'discountedPrice': 994,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/39/thumbnail.jpg'}],
#    'total': 2328,
#    'discountedTotal': 1941,
#    'userId': 97,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 2,
#    'products': [{'id': 96,
#      'title': 'lighting ceiling kitchen',
#      'price': 30,
#      'quantity': 2,
#      'total': 60,
#      'discountPercentage': 14.89,
#      'discountedPrice': 51,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/96/thumbnail.jpg'},
#     {'id': 91,
#      'title': 'Black Motorbike',
#      'price': 569,
#      'quantity': 3,
#      'total': 1707,
#      'discountPercentage': 13.63,
#      'discountedPrice': 1474,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/91/thumbnail.jpg'},
#     {'id': 9,
#      'title': 'Infinix INBOOK',
#      'price': 1099,
#      'quantity': 1,
#      'total': 1099,
#      'discountPercentage': 11.83,
#      'discountedPrice': 969,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/9/thumbnail.jpg'},
#     {'id': 16,
#      'title': 'Hyaluronic Acid Serum',
#      'price': 19,
#      'quantity': 1,
#      'total': 19,
#      'discountPercentage': 13.31,
#      'discountedPrice': 16,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/16/thumbnail.jpg'},
#     {'id': 54,
#      'title': 'Pubg Printed Graphic T-Shirt',
#      'price': 46,
#      'quantity': 3,
#      'total': 138,
#      'discountPercentage': 16.44,
#      'discountedPrice': 115,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/54/thumbnail.jpg'}],
#    'total': 3023,
#    'discountedTotal': 2625,
#    'userId': 30,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 3,
#    'products': [{'id': 37,
#      'title': 'ank Tops for Womens/Girls',
#      'price': 50,
#      'quantity': 2,
#      'total': 100,
#      'discountPercentage': 12.05,
#      'discountedPrice': 88,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/37/thumbnail.jpg'},
#     {'id': 80,
#      'title': 'Chain Pin Tassel Earrings',
#      'price': 45,
#      'quantity': 3,
#      'total': 135,
#      'discountPercentage': 17.75,
#      'discountedPrice': 111,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/80/thumbnail.jpg'},
#     {'id': 68,
#      'title': 'Stylish Luxury Digital Watch',
#      'price': 57,
#      'quantity': 3,
#      'total': 171,
#      'discountPercentage': 9.03,
#      'discountedPrice': 156,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/68/thumbnail.webp'},
#     {'id': 81,
#      'title': 'Round Silver Frame Sun Glasses',
#      'price': 19,
#      'quantity': 1,
#      'total': 19,
#      'discountPercentage': 10.1,
#      'discountedPrice': 17,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/81/thumbnail.jpg'},
#     {'id': 90,
#      'title': 'Cycle Bike Glow',
#      'price': 35,
#      'quantity': 1,
#      'total': 35,
#      'discountPercentage': 11.08,
#      'discountedPrice': 31,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/90/thumbnail.jpg'}],
#    'total': 460,
#    'discountedTotal': 403,
#    'userId': 63,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 4,
#    'products': [{'id': 36,
#      'title': 'Sleeve Shirt Womens',
#      'price': 90,
#      'quantity': 1,
#      'total': 90,
#      'discountPercentage': 10.89,
#      'discountedPrice': 80,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/36/thumbnail.jpg'},
#     {'id': 54,
#      'title': 'Pubg Printed Graphic T-Shirt',
#      'price': 46,
#      'quantity': 1,
#      'total': 46,
#      'discountPercentage': 16.44,
#      'discountedPrice': 38,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/54/thumbnail.jpg'},
#     {'id': 11,
#      'title': 'perfume Oil',
#      'price': 13,
#      'quantity': 3,
#      'total': 39,
#      'discountPercentage': 8.4,
#      'discountedPrice': 36,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/11/thumbnail.jpg'},
#     {'id': 47,
#      'title': 'Sneaker shoes',
#      'price': 120,
#      'quantity': 2,
#      'total': 240,
#      'discountPercentage': 10.37,
#      'discountedPrice': 215,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/47/thumbnail.jpeg'},
#     {'id': 64,
#      'title': 'Leather Strap Skeleton Watch',
#      'price': 46,
#      'quantity': 3,
#      'total': 138,
#      'discountPercentage': 10.2,
#      'discountedPrice': 124,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/64/thumbnail.jpg'}],
#    'total': 553,
#    'discountedTotal': 493,
#    'userId': 83,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 5,
#    'products': [{'id': 23,
#      'title': 'Orange Essence Food Flavou',
#      'price': 14,
#      'quantity': 3,
#      'total': 42,
#      'discountPercentage': 8.04,
#      'discountedPrice': 39,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/23/thumbnail.jpg'},
#     {'id': 91,
#      'title': 'Black Motorbike',
#      'price': 569,
#      'quantity': 1,
#      'total': 569,
#      'discountPercentage': 13.63,
#      'discountedPrice': 491,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/91/thumbnail.jpg'},
#     {'id': 45,
#      'title': 'Malai Maxi Dress',
#      'price': 50,
#      'quantity': 2,
#      'total': 100,
#      'discountPercentage': 5.07,
#      'discountedPrice': 95,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/45/thumbnail.jpg'},
#     {'id': 84,
#      'title': 'Square Sunglasses',
#      'price': 28,
#      'quantity': 1,
#      'total': 28,
#      'discountPercentage': 13.89,
#      'discountedPrice': 24,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/84/thumbnail.jpg'},
#     {'id': 70,
#      'title': 'Stainless Steel Women',
#      'price': 35,
#      'quantity': 3,
#      'total': 105,
#      'discountPercentage': 8.98,
#      'discountedPrice': 96,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/70/thumbnail.jpg'}],
#    'total': 844,
#    'discountedTotal': 745,
#    'userId': 58,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 6,
#    'products': [{'id': 53,
#      'title': 'printed high quality T shirts',
#      'price': 35,
#      'quantity': 3,
#      'total': 105,
#      'discountPercentage': 7.54,
#      'discountedPrice': 97,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/53/thumbnail.jpg'},
#     {'id': 61,
#      'title': 'Leather Straps Wristwatch',
#      'price': 120,
#      'quantity': 2,
#      'total': 240,
#      'discountPercentage': 7.14,
#      'discountedPrice': 223,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/61/thumbnail.jpg'},
#     {'id': 92,
#      'title': 'HOT SALE IN EUROPE electric racing motorcycle',
#      'price': 920,
#      'quantity': 1,
#      'total': 920,
#      'discountPercentage': 14.4,
#      'discountedPrice': 788,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/92/thumbnail.jpg'},
#     {'id': 11,
#      'title': 'perfume Oil',
#      'price': 13,
#      'quantity': 3,
#      'total': 39,
#      'discountPercentage': 8.4,
#      'discountedPrice': 36,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/11/thumbnail.jpg'},
#     {'id': 37,
#      'title': 'ank Tops for Womens/Girls',
#      'price': 50,
#      'quantity': 3,
#      'total': 150,
#      'discountPercentage': 12.05,
#      'discountedPrice': 132,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/37/thumbnail.jpg'}],
#    'total': 1454,
#    'discountedTotal': 1276,
#    'userId': 26,
#    'totalProducts': 5,
#    'totalQuantity': 12},
#   {'id': 7,
#    'products': [{'id': 61,
#      'title': 'Leather Straps Wristwatch',
#      'price': 120,
#      'quantity': 1,
#      'total': 120,
#      'discountPercentage': 7.14,
#      'discountedPrice': 111,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/61/thumbnail.jpg'},
#     {'id': 80,
#      'title': 'Chain Pin Tassel Earrings',
#      'price': 45,
#      'quantity': 2,
#      'total': 90,
#      'discountPercentage': 17.75,
#      'discountedPrice': 74,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/80/thumbnail.jpg'},
#     {'id': 99,
#      'title': 'American Vintage Wood Pendant Light',
#      'price': 46,
#      'quantity': 3,
#      'total': 138,
#      'discountPercentage': 8.84,
#      'discountedPrice': 126,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/99/thumbnail.jpg'},
#     {'id': 14,
#      'title': 'Non-Alcoholic Concentrated Perfume Oil',
#      'price': 120,
#      'quantity': 1,
#      'total': 120,
#      'discountPercentage': 15.6,
#      'discountedPrice': 101,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/14/thumbnail.jpg'},
#     {'id': 48,
#      'title': 'Women Strip Heel',
#      'price': 40,
#      'quantity': 3,
#      'total': 120,
#      'discountPercentage': 10.83,
#      'discountedPrice': 107,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/48/thumbnail.jpg'}],
#    'total': 588,
#    'discountedTotal': 519,
#    'userId': 56,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 8,
#    'products': [{'id': 45,
#      'title': 'Malai Maxi Dress',
#      'price': 50,
#      'quantity': 1,
#      'total': 50,
#      'discountPercentage': 5.07,
#      'discountedPrice': 47,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/45/thumbnail.jpg'},
#     {'id': 83,
#      'title': 'Wiley X Night Vision Yellow Glasses',
#      'price': 30,
#      'quantity': 3,
#      'total': 90,
#      'discountPercentage': 6.33,
#      'discountedPrice': 84,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/83/thumbnail.jpg'},
#     {'id': 96,
#      'title': 'lighting ceiling kitchen',
#      'price': 30,
#      'quantity': 1,
#      'total': 30,
#      'discountPercentage': 14.89,
#      'discountedPrice': 26,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/96/thumbnail.jpg'},
#     {'id': 21,
#      'title': '- Daal Masoor 500 grams',
#      'price': 20,
#      'quantity': 3,
#      'total': 60,
#      'discountPercentage': 4.81,
#      'discountedPrice': 57,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/21/thumbnail.png'},
#     {'id': 2,
#      'title': 'iphone X',
#      'price': 899,
#      'quantity': 1,
#      'total': 899,
#      'discountPercentage': 17.94,
#      'discountedPrice': 738,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/2/thumbnail.jpg'}],
#    'total': 1129,
#    'discountedTotal': 952,
#    'userId': 1,
#    'totalProducts': 5,
#    'totalQuantity': 9},
#   {'id': 9,
#    'products': [{'id': 74,
#      'title': 'Leather Hand Bag',
#      'price': 57,
#      'quantity': 3,
#      'total': 171,
#      'discountPercentage': 11.19,
#      'discountedPrice': 152,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/74/thumbnail.jpg'},
#     {'id': 10,
#      'title': 'HP Pavilion 15-DK1056WM',
#      'price': 1099,
#      'quantity': 3,
#      'total': 3297,
#      'discountPercentage': 6.18,
#      'discountedPrice': 3093,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/10/thumbnail.jpeg'},
#     {'id': 19,
#      'title': 'Skin Beauty Serum.',
#      'price': 46,
#      'quantity': 2,
#      'total': 92,
#      'discountPercentage': 10.68,
#      'discountedPrice': 82,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/19/thumbnail.jpg'},
#     {'id': 53,
#      'title': 'printed high quality T shirts',
#      'price': 35,
#      'quantity': 1,
#      'total': 35,
#      'discountPercentage': 7.54,
#      'discountedPrice': 32,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/53/thumbnail.jpg'},
#     {'id': 13,
#      'title': 'Fog Scent Xpressio Perfume',
#      'price': 13,
#      'quantity': 1,
#      'total': 13,
#      'discountPercentage': 8.14,
#      'discountedPrice': 12,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/13/thumbnail.webp'}],
#    'total': 3608,
#    'discountedTotal': 3371,
#    'userId': 91,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 10,
#    'products': [{'id': 75,
#      'title': 'Seven Pocket Women Bag',
#      'price': 68,
#      'quantity': 1,
#      'total': 68,
#      'discountPercentage': 14.87,
#      'discountedPrice': 58,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/75/thumbnail.jpg'},
#     {'id': 39,
#      'title': 'Women Sweaters Wool',
#      'price': 600,
#      'quantity': 1,
#      'total': 600,
#      'discountPercentage': 17.2,
#      'discountedPrice': 497,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/39/thumbnail.jpg'},
#     {'id': 3,
#      'title': 'Samsung Universe 9',
#      'price': 1249,
#      'quantity': 3,
#      'total': 3747,
#      'discountPercentage': 15.46,
#      'discountedPrice': 3168,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/3/thumbnail.jpg'},
#     {'id': 7,
#      'title': 'Samsung Galaxy Book',
#      'price': 1499,
#      'quantity': 1,
#      'total': 1499,
#      'discountPercentage': 4.15,
#      'discountedPrice': 1437,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/7/thumbnail.jpg'},
#     {'id': 93,
#      'title': 'Automatic Motor Gas Motorcycles',
#      'price': 1050,
#      'quantity': 3,
#      'total': 3150,
#      'discountPercentage': 3.34,
#      'discountedPrice': 3045,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/93/thumbnail.jpg'}],
#    'total': 9064,
#    'discountedTotal': 8205,
#    'userId': 13,
#    'totalProducts': 5,
#    'totalQuantity': 9},
#   {'id': 11,
#    'products': [{'id': 71,
#      'title': 'Women Shoulder Bags',
#      'price': 46,
#      'quantity': 3,
#      'total': 138,
#      'discountPercentage': 14.65,
#      'discountedPrice': 118,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/71/thumbnail.jpg'},
#     {'id': 25,
#      'title': 'Gulab Powder 50 Gram',
#      'price': 70,
#      'quantity': 2,
#      'total': 140,
#      'discountPercentage': 13.58,
#      'discountedPrice': 121,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/25/thumbnail.jpg'},
#     {'id': 65,
#      'title': 'Stainless Steel Wrist Watch',
#      'price': 47,
#      'quantity': 3,
#      'total': 141,
#      'discountPercentage': 17.79,
#      'discountedPrice': 116,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/65/thumbnail.webp'},
#     {'id': 58,
#      'title': 'formal offices shoes',
#      'price': 57,
#      'quantity': 1,
#      'total': 57,
#      'discountPercentage': 12,
#      'discountedPrice': 50,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/58/thumbnail.jpg'},
#     {'id': 53,
#      'title': 'printed high quality T shirts',
#      'price': 35,
#      'quantity': 3,
#      'total': 105,
#      'discountPercentage': 7.54,
#      'discountedPrice': 97,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/53/thumbnail.jpg'}],
#    'total': 581,
#    'discountedTotal': 502,
#    'userId': 66,
#    'totalProducts': 5,
#    'totalQuantity': 12},
#   {'id': 12,
#    'products': [{'id': 32,
#      'title': 'Sofa for Coffe Cafe',
#      'price': 50,
#      'quantity': 2,
#      'total': 100,
#      'discountPercentage': 15.59,
#      'discountedPrice': 84,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/32/thumbnail.jpg'},
#     {'id': 41,
#      'title': 'NIGHT SUIT',
#      'price': 55,
#      'quantity': 3,
#      'total': 165,
#      'discountPercentage': 15.05,
#      'discountedPrice': 140,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/41/thumbnail.webp'},
#     {'id': 69,
#      'title': 'Golden Watch Pearls Bracelet Watch',
#      'price': 47,
#      'quantity': 1,
#      'total': 47,
#      'discountPercentage': 17.55,
#      'discountedPrice': 39,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/69/thumbnail.jpg'},
#     {'id': 98,
#      'title': '3 lights lndenpant kitchen islang',
#      'price': 34,
#      'quantity': 3,
#      'total': 102,
#      'discountPercentage': 5.92,
#      'discountedPrice': 96,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/98/thumbnail.jpg'},
#     {'id': 67,
#      'title': 'Fashion Magnetic Wrist Watch',
#      'price': 60,
#      'quantity': 2,
#      'total': 120,
#      'discountPercentage': 16.69,
#      'discountedPrice': 100,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/67/thumbnail.jpg'}],
#    'total': 534,
#    'discountedTotal': 459,
#    'userId': 52,
#    'totalProducts': 5,
#    'totalQuantity': 11},
#   {'id': 13,
#    'products': [{'id': 81,
#      'title': 'Round Silver Frame Sun Glasses',
#      'price': 19,
#      'quantity': 1,
#      'total': 19,
#      'discountPercentage': 10.1,
#      'discountedPrice': 17,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/81/thumbnail.jpg'},
#     {'id': 42,
#      'title': 'Stiched Kurta plus trouser',
#      'price': 80,
#      'quantity': 2,
#      'total': 160,
#      'discountPercentage': 15.37,
#      'discountedPrice': 135,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/42/thumbnail.jpg'},
#     {'id': 29,
#      'title': 'Handcraft Chinese style',
#      'price': 60,
#      'quantity': 3,
#      'total': 180,
#      'discountPercentage': 15.34,
#      'discountedPrice': 152,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/29/thumbnail.webp'},
#     {'id': 64,
#      'title': 'Leather Strap Skeleton Watch',
#      'price': 46,
#      'quantity': 2,
#      'total': 92,
#      'discountPercentage': 10.2,
#      'discountedPrice': 83,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/64/thumbnail.jpg'},
#     {'id': 54,
#      'title': 'Pubg Printed Graphic T-Shirt',
#      'price': 46,
#      'quantity': 1,
#      'total': 46,
#      'discountPercentage': 16.44,
#      'discountedPrice': 38,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/54/thumbnail.jpg'}],
#    'total': 497,
#    'discountedTotal': 425,
#    'userId': 79,
#    'totalProducts': 5,
#    'totalQuantity': 9},
#   {'id': 14,
#    'products': [{'id': 64,
#      'title': 'Leather Strap Skeleton Watch',
#      'price': 46,
#      'quantity': 2,
#      'total': 92,
#      'discountPercentage': 10.2,
#      'discountedPrice': 83,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/64/thumbnail.jpg'},
#     {'id': 76,
#      'title': 'Silver Ring Set Women',
#      'price': 70,
#      'quantity': 2,
#      'total': 140,
#      'discountPercentage': 13.57,
#      'discountedPrice': 121,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/76/thumbnail.jpg'},
#     {'id': 30,
#      'title': 'Key Holder',
#      'price': 30,
#      'quantity': 2,
#      'total': 60,
#      'discountPercentage': 2.92,
#      'discountedPrice': 58,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/30/thumbnail.jpg'},
#     {'id': 88,
#      'title': 'TC Reusable Silicone Magic Washing Gloves',
#      'price': 29,
#      'quantity': 1,
#      'total': 29,
#      'discountPercentage': 3.19,
#      'discountedPrice': 28,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/88/thumbnail.jpg'},
#     {'id': 94,
#      'title': 'new arrivals Fashion motocross goggles',
#      'price': 900,
#      'quantity': 2,
#      'total': 1800,
#      'discountPercentage': 3.85,
#      'discountedPrice': 1731,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/94/thumbnail.webp'}],
#    'total': 2121,
#    'discountedTotal': 2021,
#    'userId': 76,
#    'totalProducts': 5,
#    'totalQuantity': 9},
#   {'id': 15,
#    'products': [{'id': 4,
#      'title': 'OPPOF19',
#      'price': 280,
#      'quantity': 1,
#      'total': 280,
#      'discountPercentage': 17.91,
#      'discountedPrice': 230,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/4/thumbnail.jpg'},
#     {'id': 100,
#      'title': 'Crystal chandelier maria theresa for 12 light',
#      'price': 47,
#      'quantity': 3,
#      'total': 141,
#      'discountPercentage': 16,
#      'discountedPrice': 118,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/100/thumbnail.jpg'},
#     {'id': 1,
#      'title': 'iPhone 9',
#      'price': 549,
#      'quantity': 2,
#      'total': 1098,
#      'discountPercentage': 12.96,
#      'discountedPrice': 956,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/1/thumbnail.jpg'},
#     {'id': 48,
#      'title': 'Women Strip Heel',
#      'price': 40,
#      'quantity': 3,
#      'total': 120,
#      'discountPercentage': 10.83,
#      'discountedPrice': 107,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/48/thumbnail.jpg'},
#     {'id': 94,
#      'title': 'new arrivals Fashion motocross goggles',
#      'price': 900,
#      'quantity': 3,
#      'total': 2700,
#      'discountPercentage': 3.85,
#      'discountedPrice': 2596,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/94/thumbnail.webp'}],
#    'total': 4339,
#    'discountedTotal': 4007,
#    'userId': 47,
#    'totalProducts': 5,
#    'totalQuantity': 12},
#   {'id': 16,
#    'products': [{'id': 3,
#      'title': 'Samsung Universe 9',
#      'price': 1249,
#      'quantity': 3,
#      'total': 3747,
#      'discountPercentage': 15.46,
#      'discountedPrice': 3168,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/3/thumbnail.jpg'},
#     {'id': 50,
#      'title': 'Women Shoes',
#      'price': 36,
#      'quantity': 3,
#      'total': 108,
#      'discountPercentage': 16.87,
#      'discountedPrice': 90,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/50/thumbnail.jpg'},
#     {'id': 67,
#      'title': 'Fashion Magnetic Wrist Watch',
#      'price': 60,
#      'quantity': 2,
#      'total': 120,
#      'discountPercentage': 16.69,
#      'discountedPrice': 100,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/67/thumbnail.jpg'},
#     {'id': 86,
#      'title': 'Bluetooth Aux',
#      'price': 25,
#      'quantity': 1,
#      'total': 25,
#      'discountPercentage': 10.56,
#      'discountedPrice': 22,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/86/thumbnail.jpg'},
#     {'id': 12,
#      'title': 'Brown Perfume',
#      'price': 40,
#      'quantity': 1,
#      'total': 40,
#      'discountPercentage': 15.66,
#      'discountedPrice': 34,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/12/thumbnail.jpg'}],
#    'total': 4040,
#    'discountedTotal': 3414,
#    'userId': 15,
#    'totalProducts': 5,
#    'totalQuantity': 10},
#   {'id': 17,
#    'products': [{'id': 12,
#      'title': 'Brown Perfume',
#      'price': 40,
#      'quantity': 3,
#      'total': 120,
#      'discountPercentage': 15.66,
#      'discountedPrice': 101,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/12/thumbnail.jpg'},
#     {'id': 25,
#      'title': 'Gulab Powder 50 Gram',
#      'price': 70,
#      'quantity': 1,
#      'total': 70,
#      'discountPercentage': 13.58,
#      'discountedPrice': 60,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/25/thumbnail.jpg'},
#     {'id': 24,
#      'title': 'cereals muesli fruit nuts',
#      'price': 46,
#      'quantity': 2,
#      'total': 92,
#      'discountPercentage': 16.8,
#      'discountedPrice': 77,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/24/thumbnail.jpg'},
#     {'id': 90,
#      'title': 'Cycle Bike Glow',
#      'price': 35,
#      'quantity': 1,
#      'total': 35,
#      'discountPercentage': 11.08,
#      'discountedPrice': 31,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/90/thumbnail.jpg'},
#     {'id': 97,
#      'title': 'Metal Ceramic Flower',
#      'price': 35,
#      'quantity': 1,
#      'total': 35,
#      'discountPercentage': 10.94,
#      'discountedPrice': 31,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/97/thumbnail.jpg'}],
#    'total': 352,
#    'discountedTotal': 300,
#    'userId': 56,
#    'totalProducts': 5,
#    'totalQuantity': 8},
#   {'id': 18,
#    'products': [{'id': 23,
#      'title': 'Orange Essence Food Flavou',
#      'price': 14,
#      'quantity': 2,
#      'total': 28,
#      'discountPercentage': 8.04,
#      'discountedPrice': 26,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/23/thumbnail.jpg'},
#     {'id': 25,
#      'title': 'Gulab Powder 50 Gram',
#      'price': 70,
#      'quantity': 2,
#      'total': 140,
#      'discountPercentage': 13.58,
#      'discountedPrice': 121,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/25/thumbnail.jpg'},
#     {'id': 9,
#      'title': 'Infinix INBOOK',
#      'price': 1099,
#      'quantity': 2,
#      'total': 2198,
#      'discountPercentage': 11.83,
#      'discountedPrice': 1938,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/9/thumbnail.jpg'},
#     {'id': 78,
#      'title': 'Rhinestone Korean Style Open Rings',
#      'price': 30,
#      'quantity': 2,
#      'total': 60,
#      'discountPercentage': 8.02,
#      'discountedPrice': 55,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/78/thumbnail.jpg'},
#     {'id': 63,
#      'title': 'Royal Blue Premium Watch',
#      'price': 50,
#      'quantity': 1,
#      'total': 50,
#      'discountPercentage': 2.56,
#      'discountedPrice': 49,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/63/thumbnail.webp'}],
#    'total': 2476,
#    'discountedTotal': 2189,
#    'userId': 42,
#    'totalProducts': 5,
#    'totalQuantity': 9},
#   {'id': 19,
#    'products': [{'id': 43,
#      'title': 'frock gold printed',
#      'price': 600,
#      'quantity': 3,
#      'total': 1800,
#      'discountPercentage': 15.55,
#      'discountedPrice': 1520,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/43/thumbnail.jpg'},
#     {'id': 77,
#      'title': 'Rose Ring',
#      'price': 100,
#      'quantity': 3,
#      'total': 300,
#      'discountPercentage': 3.22,
#      'discountedPrice': 290,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/77/thumbnail.jpg'},
#     {'id': 50,
#      'title': 'Women Shoes',
#      'price': 36,
#      'quantity': 3,
#      'total': 108,
#      'discountPercentage': 16.87,
#      'discountedPrice': 90,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/50/thumbnail.jpg'},
#     {'id': 31,
#      'title': 'Mornadi Velvet Bed',
#      'price': 40,
#      'quantity': 2,
#      'total': 80,
#      'discountPercentage': 17,
#      'discountedPrice': 66,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/31/thumbnail.jpg'},
#     {'id': 75,
#      'title': 'Seven Pocket Women Bag',
#      'price': 68,
#      'quantity': 3,
#      'total': 204,
#      'discountPercentage': 14.87,
#      'discountedPrice': 174,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/75/thumbnail.jpg'}],
#    'total': 2492,
#    'discountedTotal': 2140,
#    'userId': 5,
#    'totalProducts': 5,
#    'totalQuantity': 14},
#   {'id': 20,
#    'products': [{'id': 66,
#      'title': 'Steel Analog Couple Watches',
#      'price': 35,
#      'quantity': 3,
#      'total': 105,
#      'discountPercentage': 3.23,
#      'discountedPrice': 102,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/66/thumbnail.jpg'},
#     {'id': 59,
#      'title': 'Spring and summershoes',
#      'price': 20,
#      'quantity': 1,
#      'total': 20,
#      'discountPercentage': 8.71,
#      'discountedPrice': 18,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/59/thumbnail.jpg'},
#     {'id': 29,
#      'title': 'Handcraft Chinese style',
#      'price': 60,
#      'quantity': 1,
#      'total': 60,
#      'discountPercentage': 15.34,
#      'discountedPrice': 51,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/29/thumbnail.webp'},
#     {'id': 32,
#      'title': 'Sofa for Coffe Cafe',
#      'price': 50,
#      'quantity': 1,
#      'total': 50,
#      'discountPercentage': 15.59,
#      'discountedPrice': 42,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/32/thumbnail.jpg'},
#     {'id': 46,
#      'title': "women's shoes",
#      'price': 40,
#      'quantity': 2,
#      'total': 80,
#      'discountPercentage': 16.96,
#      'discountedPrice': 66,
#      'thumbnail': 'https://cdn.dummyjson.com/product-images/46/thumbnail.jpg'}],
#    'total': 315,
#    'discountedTotal': 279,
#    'userId': 75,
#    'totalProducts': 5,
#    'totalQuantity': 8}],
#  'total': 20,
#  'skip': 0,
#  'limit': 20}

# %%
carts = requests.get("https://dummyjson.com/carts").json()
carts['carts'][1]['products']
# Out:
# [{'id': 96,
#   'title': 'lighting ceiling kitchen',
#   'price': 30,
#   'quantity': 2,
#   'total': 60,
#   'discountPercentage': 14.89,
#   'discountedPrice': 51,
#   'thumbnail': 'https://cdn.dummyjson.com/product-images/96/thumbnail.jpg'},
#  {'id': 91,
#   'title': 'Black Motorbike',
#   'price': 569,
#   'quantity': 3,
#   'total': 1707,
#   'discountPercentage': 13.63,
#   'discountedPrice': 1474,
#   'thumbnail': 'https://cdn.dummyjson.com/product-images/91/thumbnail.jpg'},
#  {'id': 9,
#   'title': 'Infinix INBOOK',
#   'price': 1099,
#   'quantity': 1,
#   'total': 1099,
#   'discountPercentage': 11.83,
#   'discountedPrice': 969,
#   'thumbnail': 'https://cdn.dummyjson.com/product-images/9/thumbnail.jpg'},
#  {'id': 16,
#   'title': 'Hyaluronic Acid Serum',
#   'price': 19,
#   'quantity': 1,
#   'total': 19,
#   'discountPercentage': 13.31,
#   'discountedPrice': 16,
#   'thumbnail': 'https://cdn.dummyjson.com/product-images/16/thumbnail.jpg'},
#  {'id': 54,
#   'title': 'Pubg Printed Graphic T-Shirt',
#   'price': 46,
#   'quantity': 3,
#   'total': 138,
#   'discountPercentage': 16.44,
#   'discountedPrice': 115,
#   'thumbnail': 'https://cdn.dummyjson.com/product-images/54/thumbnail.jpg'}]

# %%
for product in carts['carts'][1]['products']:
    print(f"{product['title']:30}{product['price']:>10.2f}")
# Out:
# lighting ceiling kitchen           30.00
# Black Motorbike                   569.00
# Infinix INBOOK                   1099.00
# Hyaluronic Acid Serum              19.00
# Pubg Printed Graphic T-Shirt       46.00

# %%
carts['carts'][1]['products'][0]['price']
# Out:
# 30

# %% [markdown]
# # csv module
# * Used for reading and writing to from csv files
# * Works equally well for any file extension
# * Works with the open function
# * Unlike the open function you can write numerical data
# * You have to be careful of poorly written csv, i.e. extra/missing commas
# * Reserved word next reads first line for use with headers

# %%
import csv

# %%
file = open('data/spy.csv', mode='r', newline='')
reader = csv.reader(file)
header = next(reader)
data = [row for row in reader]
file.close()

# %%
print(header)
print(data)
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
# [['2023-02-01', '405.2099914550781', '413.6700134277344', '402.3500061035156', '410.79998779296875', '101459200'], ['2023-02-02', '414.8599853515625', '418.30999755859375', '412.8800048828125', '416.7799987792969', '101654500'], ['2023-02-03', '411.5899963378906', '416.9700012207031', '411.0899963378906', '412.3500061035156', '94736800'], ['2023-02-06', '409.7900085449219', '411.2900085449219', '408.1000061035156', '409.8299865722656', '60295300'], ['2023-02-07', '408.8699951171875', '416.489990234375', '407.57000732421875', '415.19000244140625', '90990700'], ['2023-02-08', '413.1300048828125', '414.5299987792969', '409.92999267578125', '410.6499938964844', '76227500'], ['2023-02-09', '414.4100036621094', '414.57000732421875', '405.80999755859375', '407.0899963378906', '78694900'], ['2023-02-10', '405.8599853515625', '408.44000244140625', '405.010009765625', '408.0400085449219', '70769700'], ['2023-02-13', '408.7200012207031', '412.9700012207031', '408.239990234375', '412.8299865722656', '64913500'], ['2023-02-14', '411.239990234375', '415.04998779296875', '408.510009765625', '412.6400146484375', '88389300'], ['2023-02-15', '410.3500061035156', '414.05999755859375', '409.4700012207031', '413.9800109863281', '61555700'], ['2023-02-16', '408.7900085449219', '412.9100036621094', '408.1400146484375', '408.2799987792969', '76431500'], ['2023-02-17', '406.05999755859375', '407.510009765625', '404.04998779296875', '407.260009765625', '89257800'], ['2023-02-21', '403.05999755859375', '404.1600036621094', '398.82000732421875', '399.0899963378906', '82655900'], ['2023-02-22', '399.5199890136719', '401.1300048828125', '397.0199890136719', '398.5400085449219', '83742300'], ['2023-02-23', '401.55999755859375', '402.20001220703125', '396.25', '400.6600036621094', '96242400'], ['2023-02-24', '395.4200134277344', '397.25', '393.6400146484375', '396.3800048828125', '108194400'], ['2023-02-27', '399.8699951171875', '401.2900085449219', '396.75', '397.7300109863281', '80444700'], ['2023-02-28', '397.2300109863281', '399.2799987792969', '396.1499938964844', '396.260009765625', '96438600'], ['2023-03-01', '395.4100036621094', '396.69000244140625', '393.3800048828125', '394.739990234375', '99706800'], ['2023-03-02', '392.67999267578125', '398.69000244140625', '392.3299865722656', '397.80999755859375', '85127800'], ['2023-03-03', '399.7099914550781', '404.45001220703125', '399.0299987792969', '404.19000244140625', '90120000'], ['2023-03-06', '405.04998779296875', '407.45001220703125', '404.010009765625', '404.4700012207031', '72795900'], ['2023-03-07', '404.4200134277344', '404.6700134277344', '397.6300048828125', '398.2699890136719', '108310600'], ['2023-03-08', '398.3900146484375', '399.7099914550781', '396.5899963378906', '398.9200134277344', '74746600'], ['2023-03-09', '399.739990234375', '401.4800109863281', '390.5299987792969', '391.55999755859375', '111945300'], ['2023-03-10', '390.989990234375', '393.1600036621094', '384.32000732421875', '385.9100036621094', '189253000'], ['2023-03-13', '381.80999755859375', '390.3900146484375', '380.6499938964844', '385.3599853515625', '157790000'], ['2023-03-14', '390.5', '393.45001220703125', '387.04998779296875', '391.7300109863281', '149752400'], ['2023-03-15', '385.8900146484375', '389.489990234375', '383.7099914550781', '389.2799987792969', '172996900'], ['2023-03-16', '386.82000732421875', '396.4700012207031', '386.2900085449219', '396.1099853515625', '143254200'], ['2023-03-17', '393.2200012207031', '394.3999938964844', '388.54998779296875', '389.989990234375', '140553400'], ['2023-03-20', '390.79998779296875', '394.1700134277344', '390.07000732421875', '393.739990234375', '93055800'], ['2023-03-21', '397.239990234375', '399.4100036621094', '395.5799865722656', '398.9100036621094', '91524200'], ['2023-03-22', '398.7300109863281', '402.489990234375', '392.07000732421875', '392.1099853515625', '111746600'], ['2023-03-23', '395.0899963378906', '399.2900085449219', '390.3500061035156', '393.170013427734 ...

# %% [markdown]
# ### Databases

# %%
import sqlite3

# %%
connection = sqlite3.connect('demo.db')
cursor = connection.cursor()

# %%
# create table
cursor.execute("DROP TABLE IF EXISTS data")
cursor.execute("""CREATE TABLE
    data(id integer primary key autoincrement,
    date text,
    open real,
    high real,
    low real,
    close real,
    volume integer)
""")

# %%
data = ["2022-02-01", 450.68, 453.63, 446.94, 452.95, 123155400]
sql = """INSERT INTO data(date, open, high, low, close, volume)
      VALUES (?,?,?,?,?,?)"""

# %%
cursor.execute(sql, data)

# %%
connection.commit()

# %%
sql = "SELECT * FROM data"
cursor.execute(sql)
result = cursor.fetchone()

# %%
print(result)
# Out:
# (1, '2022-02-01', 450.68, 453.63, 446.94, 452.95, 123155400)

# %%
connection.close()
